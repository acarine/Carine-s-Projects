# %% [markdown]
# # Module 4 Exercises - Data Visualization

# %% [markdown]
# ### Exercise 1:
#
# From the datasets folder, load the "dvddata.xlsx" file as a dataframe. Then rename the following columns (new column name is in parentheses):
# - \# of Clients (Clients)
# - Visits to each Client per Month (Visits)
# - Calls to each Client per month (Calls)
# - Emails to each Client per month (Emails)
# - \# of businesses in district (Business)

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
location ="datasets/dvddata.xlsx" 
dvddata_df = pd.read_excel(location)

# %%
dvddata_df.columns
# Out:
# Index(['Salesperson', 'District', 'Region', 'Sales', '# of Clients', 'Visits',
#        'Calls to each Client per month', 'Emails to each Client per month',
#        '# of businesses in district'],
#       dtype='object')

# %%
dvddata_df.rename(columns={'# of Clients' : 'Clients',' Visits to each Client per Month' : 'Visits',
                           'Calls to each Client per month':'Calls', 
                           'Emails to each Client per month':'Emails',
                           '# of businesses in district':'Business'}, inplace=True)
dvddata_df
# Out:
#             Salesperson  District Region  Sales  Clients  Visits  Calls  \
# 0          Addie Miller        52      A    393       16       2      4
# 1          Addie Miller        67      A    267       11       2      1
# 2          Addie Miller       104      A    148        4       1      1
# 3       Alexandra Jones        49      A    317       17       0      7
# 4        Alonzo Tennant        46      A    276       16       2      2
# 5        Alonzo Tennant        90      A    347       16       2      8
# 6        Alonzo Tennant       100      A    253       11       1      1
# 7         Andrea Kraatz        97      A    216       13       2      6
# 8         Ann Dominguez        64      A    139        4       2      5
# 9            Anna Desai       113      A    128        4       2      6
# 10        Barbara Wales        91      A    262       19       2      1
# 11        Barbara Wales       124      A    215       10       1      0
# 12         Bessie Lewis        42      A    216       13       2      0
# 13         Bessie Lukas        38      A    327       13       1      4
# 14       Bessie Mcmanus        29      A    159       15       2      0
# 15       Bessie Mcmanus        55      A    185        7       2      7
# 16       Bessie Mcmanus       117      A    244       22       0      2
# 17        Caroline Boyd        70      A    526       20       0      7
# 18    Charlotte Simmons        27      A    470       17       0      6
# 19    Charlotte Simmons        74      A    415       22       0      6
# 20       Charmain Crisp        35      A    472       21       2      3
# 21      Christine Lopez        68      A     72        2       0      5
# 22  Christopher Alvardo        72      A    150        8       1      0
# 23  Christopher Alvardo        82      A     75        5       2      7
# 24      Connie Douglass        75      B    321       12       2      2
# 25      Cynthia Conklin        51      B    305       22       0      0
# 26      Cynthia Conklin       119      B    281       10       2      6
# 27      Cynthia Ellison        58      B    412       16       0      0
# 28        Deborah Seals        61      B    253        9       1      7
# 29        Deborah Seals        69      B    378       21       1      0
# ..                  ...       ...    ...    ...      ...     ...    ...
# 70           Lorna Kyle        94      C    105        4       1      7
# 71      Margaret Cooper       115      C    166       10       0      6
# 72      Margie Thrasher       118      C    295       21       1      7
# 73      Marilyn Sandler        43      C    248       11       2      6
# 74        Marisol Rosen       120      C    229        9       2      0
# 75        Martha Fabian        87      D    212       11       1      5
# 76         Mary Adamson        30      D    228       19       0      5
# 77        Mary Gauthier        60      D    193       12       0      6
# 78           Mary Smith        88      D     56        2       1      0
# 79          Megan Gault       125      D    263       14       1      4
# 80         Moses Chavez        81      D    149       10       1      5
# 81          Myrna Ellis        71      D    336       18       2      0
# 82         Nina Kennedy       107      D    311       16       2      8
# 83       Pamala Darrell        32      D    484       21       1      2
# 84      Rachel Griffith        83      D    457       18       0      7
# 85        Robert Liston       103      D    135        4       1      6
# 86        Ruby Meyerson        95      D     74        5       0      1
# 87       Sally Vineyard        59      D    457       20       1      2
# 88        Samuel Cuyler        96      D    232       19       1      3
# 89          Sarah Ellis        99      D    405       20       0      7
# 90           Sarah Hall        40      D    148        6       2      5
# 91     Sherry Davenport       123      D    391       15       2      3
# 92         Shirley Vick        86      D    303       22       1      1
# 93       Sonia Greenman        78      D    372       22       0      0
# 94        Susan J. Ward        37      D    244       11       2      3
# 95        Tammy Stowers       122      D    374       15       0      2
# 96         Terri Taylor        89      D    181       11       2      2
# 97         Terry Bonner       114      D    200        8       2      8
# 98        Terry Donnell        41      D    287       22       1      6
# 99        Trudy Vaughan        98      D    561       22       1      5
#
#     Emails  Business
# 0       30       500
# 1       14       627
# 2       17       778
# 3        1       530
# 4       22       770
# 5       21       288
# 6        3       875
# 7       11        25
# 8       29       926
# 9       26       596
# 10      25       783
# 11      10       739
# 12      26       720
# 13       5        91
# 14      11        33
# 15      26        57
# 16       3       400
# 17      23       645
# 18      10       361
# 19      18       213
# 20      30       234
# 21       3       909
# 22      20       584
# 23      28       634
# 24       4       705
# 25      24       383
# 26      14       279
# 27       1       489
# 28       1       518
# 29      29       167
# ..     ...       ...
# 70      19       255
# 71       7        87
# 72      17       248
# 73      10       394
# 74       2       965
# 75      20       673
# 76      27       420
# 77      29       427
# 78      20       839
# 79       0       701
# 80      27       232
# 81      27       473
# 82       3        22
# 83      17       619
# 84      11       714
# 85       4       489
# 86      21       388
# 87      11       626
# 88      18       370
# 89      13       510
# 90      22       987
# 91      27       540
# 92      16       420
# 93       4       846
# 94      10       514
# 95      26       850
# 96       9       315
# 97      18       644
# 98      21       519
# 99      20       192
#
# [100 rows x 9 columns]

# %% [markdown]
# ### Exercise 2:
#
# Using the dataframe from the previous exercise, use the Seaborn library to create a scatterplot of the number of clients compared to the sales.

# %%
sns.lmplot(x='Clients', y='Sales', data= dvddata_df)

# %% [markdown]
# ### Exercise 3:
#
# Using the dataframe in the previous exercise, use the Seaborn library to make a boxplot of the Clients, Visits, Calls, and Emails columns. (**Hint**: Make a dataframe that only contains those columns)

# %%
dvddata_df1 = dvddata_df[['Clients', 'Visits','Calls', 'Emails']]
dvddata_df1
# Out:
#     Clients  Visits  Calls  Emails
# 0        16       2      4      30
# 1        11       2      1      14
# 2         4       1      1      17
# 3        17       0      7       1
# 4        16       2      2      22
# 5        16       2      8      21
# 6        11       1      1       3
# 7        13       2      6      11
# 8         4       2      5      29
# 9         4       2      6      26
# 10       19       2      1      25
# 11       10       1      0      10
# 12       13       2      0      26
# 13       13       1      4       5
# 14       15       2      0      11
# 15        7       2      7      26
# 16       22       0      2       3
# 17       20       0      7      23
# 18       17       0      6      10
# 19       22       0      6      18
# 20       21       2      3      30
# 21        2       0      5       3
# 22        8       1      0      20
# 23        5       2      7      28
# 24       12       2      2       4
# 25       22       0      0      24
# 26       10       2      6      14
# 27       16       0      0       1
# 28        9       1      7       1
# 29       21       1      0      29
# ..      ...     ...    ...     ...
# 70        4       1      7      19
# 71       10       0      6       7
# 72       21       1      7      17
# 73       11       2      6      10
# 74        9       2      0       2
# 75       11       1      5      20
# 76       19       0      5      27
# 77       12       0      6      29
# 78        2       1      0      20
# 79       14       1      4       0
# 80       10       1      5      27
# 81       18       2      0      27
# 82       16       2      8       3
# 83       21       1      2      17
# 84       18       0      7      11
# 85        4       1      6       4
# 86        5       0      1      21
# 87       20       1      2      11
# 88       19       1      3      18
# 89       20       0      7      13
# 90        6       2      5      22
# 91       15       2      3      27
# 92       22       1      1      16
# 93       22       0      0       4
# 94       11       2      3      10
# 95       15       0      2      26
# 96       11       2      2       9
# 97        8       2      8      18
# 98       22       1      6      21
# 99       22       1      5      20
#
# [100 rows x 4 columns]

# %%
sns.boxplot(data=dvddata_df1)

# %% [markdown]
# ### Exercise 4:
#
# Using the dataframe from Exercise 3, use the Seaborn library to make a violin plot of sales per region.

# %%
plt.subplots(figsize=(8,5))
sns.violinplot(x='Region', y='Sales', data=dvddata_df)

# %% [markdown]
# ### Exercise 5:
#
# Using the dataframe in the previous exercise, create a swarm plot of sales per region.

# %%
plt.subplots(figsize=(10,6))
sns.swarmplot(x='Region', y='Sales', data=dvddata_df)

# %% [markdown]
# ### Exercise 6:
#
# Using the dataframe in the previous exercise, make a correlation heatmap.

# %%
#show correlation of stats via heatmap
corr =dvddata_df.corr()

sns.heatmap(corr, vmin=-1, annot=True)

# %% [markdown]
# ### Exercise 7:
#
# Using the dataframe in the previous exercise, make a bar chart (count plot) of the regions.

# %%
sns.countplot(x='Region',
              data=dvddata_df)

# %% [markdown]
# ### Bonus
#
# Feel free to explore any other data visualizations using the Seaborn library.
