# %%
import pandas as pd
import numpy as np
import seaborn; seaborn.set()
import matplotlib.pyplot as plt

from datetime import datetime

# %matplotlib inline

# %%
location = "DC_Properties.csv"
df = pd.read_csv(location)
df.head()
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL  ...  LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0  ... -77.040832       Old City 2   040 D Old City 2
# 1  1898.0   2007.0  ... -77.040764       Old City 2   040 D Old City 2
# 2  1910.0   2009.0  ... -77.040678       Old City 2   040 D Old City 2
# 3  1900.0   2003.0  ... -77.040629       Old City 2   040 D Old City 2
# 4  1913.0   2012.0  ... -77.039361       Old City 2   040 D Old City 2
#
#    CENSUS_TRACT CENSUS_BLOCK    WARD  SQUARE          X          Y QUADRANT
# ...

# %%
location = "DC_Properties.csv"
df = pd.read_csv(location)
df
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 0                0       4          0      Warm Cool  Y        2.0      8
# 1                1       3          1      Warm Cool  Y        2.0     11
# 2                2       3          1  Hot Water Rad  Y        2.0      9
# 3                3       3          1  Hot Water Rad  Y        2.0      8
# 4                4       2          1      Warm Cool  Y        1.0     11
# 5                5       3          2  Hot Water Rad  Y        1.0     10
# 6                6       1          0      Warm Cool  Y        2.0      5
# 7                7       3          1  Hot Water Rad  Y        2.0      8
# 8                8       3          1      Warm Cool  Y        2.0      7
# 9                9       1          1  Hot Water Rad  Y        1.0      6
# 10              10       3          0     Forced Air  N        3.0     12
# 11              11       5          0  Hot Water Rad  Y        3.0     16
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
#        'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
#Create data with only rooms, price, quadrant, assessment of neighboor, ward, square footage
df1 = df [['ROOMS','PRICE','CNDTN','QUADRANT','ASSESSMENT_NBHD','WARD','ZIPCODE','SQUARE']]
df1
# Out:
#         ROOMS      PRICE      CNDTN QUADRANT       ASSESSMENT_NBHD    WARD  \
# 0           8  1095000.0       Good       NW            Old City 2  Ward 2
# 1          11        NaN       Good       NW            Old City 2  Ward 2
# 2           9  2100000.0  Very Good       NW            Old City 2  Ward 2
# 3           8  1602000.0       Good       NW            Old City 2  Ward 2
# 4          11        NaN       Good       NW            Old City 2  Ward 2
# 5          10  1950000.0       Good       NW            Old City 2  Ward 2
# 6           5        NaN    Average       NW            Old City 2  Ward 2
# 7           8  1050000.0    Average       NW            Old City 2  Ward 2
# 8           7  1430000.0  Very Good       NW            Old City 2  Ward 2
# 9           6        NaN    Average       NW            Old City 2  Ward 2
# 10         12        NaN       Fair       NW            Old City 2  Ward 2
# ...

# %%
df1['QUADRANT'].dropna(inplace=True)

# %%
#find any NaN
df1.isna().sum()
# Out:
# ROOMS                  0
# PRICE              60741
# CNDTN              52261
# QUADRANT             237
# ASSESSMENT_NBHD        1
# WARD                   1
# ZIPCODE                1
# SQUARE                 0
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# ROOMS                  0
# PRICE              60741
# CNDTN              52261
# QUADRANT             237
# ASSESSMENT_NBHD        1
# WARD                   1
# ZIPCODE                1
# SQUARE                 0
# dtype: int64

# %%
#replace all missing price values with the mean
df1_filledPrices = df1.fillna(df1['PRICE'].mean())

# %%
df1_filledPrices.head()
# Out:
#    ROOMS         PRICE      CNDTN QUADRANT ASSESSMENT_NBHD    WARD  ZIPCODE  \
# 0      8  1.095000e+06       Good       NW      Old City 2  Ward 2  20009.0
# 1     11  9.313516e+05       Good       NW      Old City 2  Ward 2  20009.0
# 2      9  2.100000e+06  Very Good       NW      Old City 2  Ward 2  20009.0
# 3      8  1.602000e+06       Good       NW      Old City 2  Ward 2  20009.0
# 4     11  9.313516e+05       Good       NW      Old City 2  Ward 2  20009.0
#
#   SQUARE
# 0    152
# 1    152
# 2    152
# 3    152
# 4    152

# %%
df1_filledPrices['PRICE'].min()
# Out:
# 1.0

# %%
#Correlation between number of rooms and price
corr = df1_filledPrices.corr()

# %%
print(corr)
# Out:
#             ROOMS     PRICE   ZIPCODE
# ROOMS    1.000000 -0.030285  0.004247
# PRICE   -0.030285  1.000000  0.000008
# ZIPCODE  0.004247  0.000008  1.000000

# %%
seaborn.heatmap(corr, vmin=-1, annot=True)

# %%
#Grouping the houses by Quadrant --> Relationship of Price & Quadrant
df1_Price_Quadrant= df1_filledPrices.groupby('QUADRANT')['PRICE'].mean()

# %%
df1_Price_Quadrant
# Out:
# QUADRANT
# 931351.5949336156    7.279510e+05
# NE                   6.201409e+05
# NW                   1.179969e+06
# SE                   6.033512e+05
# SW                   5.378592e+05
# Name: PRICE, dtype: float64

# %%
#Grouping houses by Condition ---> Relationship of Price & Condition
df1_filledPrices.groupby('CNDTN')['PRICE'].mean()
# Out:
# CNDTN
# 931351.5949336156    1.320712e+06
# Average              7.021117e+05
# Default              2.528646e+06
# Excellent            1.141737e+06
# Fair                 7.300686e+05
# Good                 7.419648e+05
# Poor                 6.884415e+05
# Very Good            9.430482e+05
# Name: PRICE, dtype: float64

# %%
plt.figure(figsize=(20,10))
seaborn.lmplot(x='ZIPCODE', y='PRICE', data=df1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-92-1a399046a720> in <module>
#       1 plt.figure(figsize=(20,10))
# ----> 2 seaborn.lmplot(x='ZIPCODE', y='PRICE', data=df1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, size)
#     587         scatter_kws=scatter_kws, line_kws=line_kws,
#     588         )
# --> 589     facets.map_dataframe(regplot, x, y, **regplot_kws)
#     590
#     591     # Add a legend
#
# ...

# %%
#swarm plot of Stats from melted dataframe
seaborn.swarmplot(x='ZIPCODE', y='PRICE', 
              data=df1_filledPrices,
              hue='CNDTN')

# %%
#Findings: Price of DC houses are affected by their location and condition
    #some of the affecting factors are quadrant and zipcode location and the rated condition of the house
